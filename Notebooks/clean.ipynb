# %%
import pandas as pd
import numpy as np

df = pd.read_csv("../Data/Raw/GoogleAds_DataAnalytics_Sales_Uncleaned.csv")
df.head()
# Out:
#    Ad_ID          Campaign_Name  Clicks  Impressions     Cost  Leads  \
# 0  A1000    DataAnalyticsCourse   104.0       4498.0  $231.88   14.0
# 1  A1001    DataAnalyticsCourse   173.0       5107.0  $216.84   10.0
# 2  A1002    Data Anlytics Corse    90.0       4544.0  $203.66   26.0
# 3  A1003  Data Analytcis Course   142.0       3185.0  $237.66   17.0
# 4  A1004   Data Analytics Corse   156.0       3361.0   $195.9   30.0
#
#    Conversions  Conversion Rate Sale_Amount     Ad_Date   Location   Device  \
# 0          7.0            0.058       $1892  2024-11-16  hyderabad  desktop
# 1          8.0            0.046       $1679  20-11-2024  hyderabad   mobile
# 2          9.0              NaN       $1624  2024/11/16  hyderabad  Desktop
# 3          6.0              NaN       $1225  2024-11-26  HYDERABAD   tablet
# 4          8.0              NaN       $1091  2024-11-22  hyderabad  desktop
#
#                   Keyword
# 0    learn data analytics
# 1   data analytics course
# 2   data analitics online
# 3  data anaytics training
# 4    online data analytic

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2600 entries, 0 to 2599
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Ad_ID            2600 non-null   str
#  1   Campaign_Name    2600 non-null   str
#  2   Clicks           2488 non-null   float64
#  3   Impressions      2546 non-null   float64
#  4   Cost             2503 non-null   str
#  5   Leads            2552 non-null   float64
#  6   Conversions      2526 non-null   float64
#  7   Conversion Rate  1974 non-null   float64
#  8   Sale_Amount      2461 non-null   str
#  9   Ad_Date          2600 non-null   str
#  10  Location         2600 non-null   str
#  11  Device           2600 non-null   str
#  12  Keyword          2600 non-null   str
# dtypes: float64(5), str(8)
# memory usage: 264.2 KB

# %%
df.describe()
# Out:
#             Clicks  Impressions        Leads  Conversions  Conversion Rate
# count  2488.000000  2546.000000  2552.000000  2526.000000      1974.000000
# mean    138.956994  4523.280833    20.003918     6.519002         0.048979
# std      34.619376   869.927913     6.032317     2.272573         0.019987
# min      80.000000  3000.000000    10.000000     3.000000         0.015000
# 25%     110.000000  3764.000000    15.000000     5.000000         0.035000
# 50%     139.000000  4518.500000    20.000000     7.000000         0.046000
# 75%     169.000000  5279.500000    25.000000     9.000000         0.058000
# max     199.000000  5999.000000    30.000000    10.000000         0.123000

# %%
df.isnull().sum()
# Out:
# Ad_ID                0
# Campaign_Name        0
# Clicks             112
# Impressions         54
# Cost                97
# Leads               48
# Conversions         74
# Conversion Rate    626
# Sale_Amount        139
# Ad_Date              0
# Location             0
# Device               0
# Keyword              0
# dtype: int64

# %%
df["Conversion Rate"].value_counts()
# Out:
# Conversion Rate
# 0.050    51
# 0.045    51
# 0.036    51
# 0.037    50
# 0.038    49
#          ..
# 0.108     2
# 0.114     1
# 0.123     1
# 0.113     1
# 0.109     1
# Name: count, Length: 105, dtype: int64

# %%
df["Conversion Rate"].describe()
# Out:
# count    1974.000000
# mean        0.048979
# std         0.019987
# min         0.015000
# 25%         0.035000
# 50%         0.046000
# 75%         0.058000
# max         0.123000
# Name: Conversion Rate, dtype: float64

# %%
df["Conversion Rate"] = df["Conversion Rate"].fillna(df["Conversion Rate"].mean())

# %%
df["Conversion Rate"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Sale_Amount"].value_counts()
# Out:
# Sale_Amount
# $1719    9
# $1248    8
# $1234    8
# $1571    8
# $1555    8
#         ..
# $1787    1
# $1302    1
# $1717    1
# $1889    1
# $1702    1
# Name: count, Length: 921, dtype: int64

# %%
#df["Sale_Amount"] = df["Sale_Amount"].str.replace('$', '', regex=False)
#df["Sale_Amount"] = df["Sale_Amount"].str.replace(',', '', regex=False)

df["Sale_Amount"] = (
    df["Sale_Amount"]
    .str.replace('$', '', regex=False)
    .str.replace(',', '', regex=False)
    .astype(float)
)

# %%
df["Sale_Amount"]
# Out:
# 0       1892.0
# 1       1679.0
# 2       1624.0
# 3       1225.0
# 4       1091.0
#          ...
# 2595    1418.0
# 2596    1950.0
# 2597    1085.0
# 2598    1558.0
# 2599    1174.0
# Name: Sale_Amount, Length: 2600, dtype: float64

# %%
df["Sale_Amount"].isnull().sum()
# Out:
# np.int64(139)

# %%
#df["Sale_Amount"] = df["Sale_Amount"].astype(int)
df["Sale_Amount"].describe()
# Out:
# count    2461.000000
# mean     1498.648111
# std       287.106579
# min      1000.000000
# 25%      1248.000000
# 50%      1505.000000
# 75%      1742.000000
# max      2000.000000
# Name: Sale_Amount, dtype: float64

# %%
df["Sale_Amount"].head()
# Out:
# 0    1892.0
# 1    1679.0
# 2    1624.0
# 3    1225.0
# 4    1091.0
# Name: Sale_Amount, dtype: float64

# %%
df["Sale_Amount"] = (
    df["Sale_Amount"]
    .fillna(df["Sale_Amount"].mean())
)

# %%
df["Sale_Amount"].isnull().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Ad_ID                0
# Campaign_Name        0
# Clicks             112
# Impressions         54
# Cost                97
# Leads               48
# Conversions         74
# Conversion Rate      0
# Sale_Amount          0
# Ad_Date              0
# Location             0
# Device               0
# Keyword              0
# dtype: int64

# %%
df["Conversions"].head().value_counts(ascending=False)
# Out:
# Conversions
# 8.0    2
# 7.0    1
# 9.0    1
# 6.0    1
# Name: count, dtype: int64

# %%
df["Conversions"].value_counts()
# Out:
# Conversions
# 7.0     345
# 9.0     330
# 5.0     324
# 4.0     313
# 10.0    306
# 8.0     304
# 6.0     302
# 3.0     302
# Name: count, dtype: int64

# %%
df["Conversions"].unique()
# Out:
# array([ 7.,  8.,  9.,  6.,  5.,  3.,  4., 10., nan])

# %%
df["Conversions"].describe()
# Out:
# count    2526.000000
# mean        6.519002
# std         2.272573
# min         3.000000
# 25%         5.000000
# 50%         7.000000
# 75%         9.000000
# max        10.000000
# Name: Conversions, dtype: float64

# %%
df["Conversions"] = (
    df["Conversions"]
    .fillna(df["Conversions"].mode()[0])
)

# %%
df["Conversions"].isnull().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Ad_ID                0
# Campaign_Name        0
# Clicks             112
# Impressions         54
# Cost                97
# Leads               48
# Conversions          0
# Conversion Rate      0
# Sale_Amount          0
# Ad_Date              0
# Location             0
# Device               0
# Keyword              0
# dtype: int64

# %%
df["Clicks"]
df.head()
# Out:
#    Ad_ID          Campaign_Name  Clicks  Impressions     Cost  Leads  \
# 0  A1000    DataAnalyticsCourse   104.0       4498.0  $231.88   14.0
# 1  A1001    DataAnalyticsCourse   173.0       5107.0  $216.84   10.0
# 2  A1002    Data Anlytics Corse    90.0       4544.0  $203.66   26.0
# 3  A1003  Data Analytcis Course   142.0       3185.0  $237.66   17.0
# 4  A1004   Data Analytics Corse   156.0       3361.0   $195.9   30.0
#
#    Conversions  Conversion Rate  Sale_Amount     Ad_Date   Location   Device  \
# 0          7.0         0.058000       1892.0  2024-11-16  hyderabad  desktop
# 1          8.0         0.046000       1679.0  20-11-2024  hyderabad   mobile
# 2          9.0         0.048979       1624.0  2024/11/16  hyderabad  Desktop
# 3          6.0         0.048979       1225.0  2024-11-26  HYDERABAD   tablet
# 4          8.0         0.048979       1091.0  2024-11-22  hyderabad  desktop
#
#                   Keyword
# 0    learn data analytics
# 1   data analytics course
# 2   data analitics online
# 3  data anaytics training
# 4    online data analytic

# %%
df["Clicks"].describe()
# Out:
# count    2488.000000
# mean      138.956994
# std        34.619376
# min        80.000000
# 25%       110.000000
# 50%       139.000000
# 75%       169.000000
# max       199.000000
# Name: Clicks, dtype: float64

# %%
df["Clicks"] = (
    df["Clicks"]
    .fillna(df["Clicks"].mean())
)

print(df["Clicks"].isnull().sum())
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Ad_ID               0
# Campaign_Name       0
# Clicks              0
# Impressions        54
# Cost               97
# Leads              48
# Conversions         0
# Conversion Rate     0
# Sale_Amount         0
# Ad_Date             0
# Location            0
# Device              0
# Keyword             0
# dtype: int64

# %%
df["Cost"]
df.head()
# Out:
#    Ad_ID          Campaign_Name  Clicks  Impressions     Cost  Leads  \
# 0  A1000    DataAnalyticsCourse   104.0       4498.0  $231.88   14.0
# 1  A1001    DataAnalyticsCourse   173.0       5107.0  $216.84   10.0
# 2  A1002    Data Anlytics Corse    90.0       4544.0  $203.66   26.0
# 3  A1003  Data Analytcis Course   142.0       3185.0  $237.66   17.0
# 4  A1004   Data Analytics Corse   156.0       3361.0   $195.9   30.0
#
#    Conversions  Conversion Rate  Sale_Amount     Ad_Date   Location   Device  \
# 0          7.0         0.058000       1892.0  2024-11-16  hyderabad  desktop
# 1          8.0         0.046000       1679.0  20-11-2024  hyderabad   mobile
# 2          9.0         0.048979       1624.0  2024/11/16  hyderabad  Desktop
# 3          6.0         0.048979       1225.0  2024-11-26  HYDERABAD   tablet
# 4          8.0         0.048979       1091.0  2024-11-22  hyderabad  desktop
#
#                   Keyword
# 0    learn data analytics
# 1   data analytics course
# 2   data analitics online
# 3  data anaytics training
# 4    online data analytic

# %%
df["Cost"] = (
    df["Cost"]
    .replace('$', '', regex=False)
    .replace(',', '', regex=False)
    .fillna(df["Cost"].mean())
)

print(df["Cost"].isnull().sum())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 5
#       1 df["Cost"] = (
#       2     df["Cost"]
#       3     .replace('$', '', regex=False)
#       4     .replace(',', '', regex=False)
# ----> 5     .fillna(df["Cost"].mean())
#       6 )
#       7
#       8 print(df["Cost"].isnull().sum())
#
# File c:\ds3\.venv\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File c:\ds3\.venv\Lib\site-packages\pandas\core\series.py:8113, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    8063 @deprecate_nonkeyword_arguments(Pandas4Warning, allowed_args=["self"], name="mean")
#    8064 def mean(
#    8065     self,
#    (...)   8069     **kwargs,
#    8070 ) -> Any:
#    8071     """
#    8072     Return the mean of the values over the requested axis.
#    8073
#    (...)   8111     2.0
#    8112     """
# -> 8113     return NDFrame.mean(
#    8114         self, axis=axis, skipna=skipna, numeric_only=numeric_only, **kwargs
#    8115     )
#
# File c:\ds3\.venv\Lib\site-packages\pandas\core\generic.py:11831, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11827         skipna: bool = True,
#   11828         numeric_only: bool = False,
#   11829         **kwargs,
#   11830     ) -> Series | float:
# > 11831         return self._stat_function(
#   11832             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11833         )
#
# File c:\ds3\.venv\Lib\site-packages\pandas\core\generic.py:11785, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11781         nv.validate_func(name, (), kwargs)
#   11782
#   11783         validate_bool_kwarg(skipna, "skipna", none_allowed=False)
#   11784
# > 11785         return self._reduce(
#   11786             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11787         )
#
# File c:\ds3\.venv\Lib\site-packages\pandas\core\series.py:7480, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    7476     self._get_axis_number(axis)
#    7478 if isinstance(delegate, ExtensionArray):
#    7479     # dispatch to ExtensionArray interface
# -> 7480     result = delegate._reduce(name, skipna=skipna, **kwds)
#    7482 else:
#    7483     # dispatch to numpy arrays
#    7484     if numeric_only and self.dtype.kind not in "iufcb":
#    7485         # i.e. not is_numeric_dtype(self.dtype)
#
# File c:\ds3\.venv\Lib\site-packages\pandas\core\arrays\string_.py:969, in StringArray._reduce(self, name, skipna, keepdims, axis, **kwargs)
#     966         return self._from_sequence([result], dtype=self.dtype)
#     967     return result
# --> 969 raise TypeError(f"Cannot perform reduction '{name}' with string dtype")
#
# TypeError: Cannot perform reduction 'mean' with string dtype

# %%
df["Cost"].head()
# Out:
# 0    231.88
# 1    216.84
# 2    203.66
# 3    237.66
# 4    195.90
# Name: Cost, dtype: float64

# %%
df.isnull().sum()
# Out:
# Ad_ID               0
# Campaign_Name       0
# Clicks              0
# Impressions        54
# Cost                0
# Leads              48
# Conversions         0
# Conversion Rate     0
# Sale_Amount         0
# Ad_Date             0
# Location            0
# Device              0
# Keyword             0
# dtype: int64

# %%
df["Impressions"]
df.head()
# Out:
#    Ad_ID          Campaign_Name  Clicks  Impressions    Cost  Leads  \
# 0  A1000    DataAnalyticsCourse   104.0       4498.0  231.88   14.0
# 1  A1001    DataAnalyticsCourse   173.0       5107.0  216.84   10.0
# 2  A1002    Data Anlytics Corse    90.0       4544.0  203.66   26.0
# 3  A1003  Data Analytcis Course   142.0       3185.0  237.66   17.0
# 4  A1004   Data Analytics Corse   156.0       3361.0  195.90   30.0
#
#    Conversions  Conversion Rate  Sale_Amount     Ad_Date   Location   Device  \
# 0          7.0         0.058000       1892.0  2024-11-16  hyderabad  desktop
# 1          8.0         0.046000       1679.0  20-11-2024  hyderabad   mobile
# 2          9.0         0.048979       1624.0  2024/11/16  hyderabad  Desktop
# 3          6.0         0.048979       1225.0  2024-11-26  HYDERABAD   tablet
# 4          8.0         0.048979       1091.0  2024-11-22  hyderabad  desktop
#
#                   Keyword
# 0    learn data analytics
# 1   data analytics course
# 2   data analitics online
# 3  data anaytics training
# 4    online data analytic

# %%
df["Impressions"].info()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 2600 entries, 0 to 2599
# Series name: Impressions
# Non-Null Count  Dtype
# --------------  -----
# 2546 non-null   float64
# dtypes: float64(1)
# memory usage: 20.4 KB

# %%
df["Impressions"].describe()
# Out:
# count    2546.000000
# mean     4523.280833
# std       869.927913
# min      3000.000000
# 25%      3764.000000
# 50%      4518.500000
# 75%      5279.500000
# max      5999.000000
# Name: Impressions, dtype: float64

# %%
df["Impressions"] = (
    df["Impressions"]
    .fillna(df["Impressions"].mean())
)

print(df["Impressions"].isnull().sum())
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Ad_ID               0
# Campaign_Name       0
# Clicks              0
# Impressions         0
# Cost                0
# Leads              48
# Conversions         0
# Conversion Rate     0
# Sale_Amount         0
# Ad_Date             0
# Location            0
# Device              0
# Keyword             0
# dtype: int64

# %%
df["Leads"].head().unique()
# Out:
# array([14., 10., 26., 17., 30.])

# %%
df["Leads"].info()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 2600 entries, 0 to 2599
# Series name: Leads
# Non-Null Count  Dtype
# --------------  -----
# 2552 non-null   float64
# dtypes: float64(1)
# memory usage: 20.4 KB

# %%
df["Leads"].describe()
# Out:
# count    2552.000000
# mean       20.003918
# std         6.032317
# min        10.000000
# 25%        15.000000
# 50%        20.000000
# 75%        25.000000
# max        30.000000
# Name: Leads, dtype: float64

# %%
df["Leads"].head(10)
# Out:
# 0    14.0
# 1    10.0
# 2    26.0
# 3    17.0
# 4    30.0
# 5    10.0
# 6    17.0
# 7    23.0
# 8    27.0
# 9    24.0
# Name: Leads, dtype: float64

# %%
df["Leads"] = (
    df["Leads"]
    .fillna(df["Leads"].mode()[0])
)

print(df["Leads"].isnull().sum())
# Out:
# 0

# %%
df["Leads"].head()
# Out:
# 0    14.0
# 1    10.0
# 2    26.0
# 3    17.0
# 4    30.0
# Name: Leads, dtype: float64

# %%
df.isnull().sum()
# Out:
# Ad_ID              0
# Campaign_Name      0
# Clicks             0
# Impressions        0
# Cost               0
# Leads              0
# Conversions        0
# Conversion Rate    0
# Sale_Amount        0
# Ad_Date            0
# Location           0
# Device             0
# Keyword            0
# dtype: int64

# %%
df.describe()
# Out:
#             Clicks  Impressions        Leads  Conversions  Conversion Rate  \
# count  2600.000000  2546.000000  2552.000000  2600.000000      2600.000000
# mean    138.956994  4523.280833    20.003918     6.532692         0.048979
# std      33.865226   869.927913     6.032317     2.241415         0.017415
# min      80.000000  3000.000000    10.000000     3.000000         0.015000
# 25%     111.000000  3764.000000    15.000000     5.000000         0.038000
# 50%     138.956994  4518.500000    20.000000     7.000000         0.048979
# 75%     167.000000  5279.500000    25.000000     8.000000         0.054000
# max     199.000000  5999.000000    30.000000    10.000000         0.123000
#
#        Sale_Amount
# count  2600.000000
# mean   1498.648111
# std     279.323553
# min    1000.000000
# 25%    1262.000000
# 50%    1498.648111
# 75%    1728.000000
# max    2000.000000

# %%
#df.to_csv("../Data/GoogleAds_DataAnalytics_Sales_Cleaned.csv", index=False)
